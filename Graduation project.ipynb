# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "heart_2022_with_nans.csv"
data=pd.read_csv(path)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              443934 non-null  object
#  3   PhysicalHealthDays         434205 non-null  float64
#  4   MentalHealthDays           436065 non-null  float64
#  5   LastCheckupTime            436824 non-null  object
#  6   PhysicalActivities         444039 non-null  object
#  7   SleepHours                 439679 non-null  float64
#  8   RemovedTeeth               433772 non-null  object
#  9   HadHeartAttack             442067 non-null  object
#  10  HadAngina                  440727 non-null  object
#  11  HadStroke                  443575 non-null  object
#  12  HadAsthma                  443359 non-null  object
# ...

# %%
data.drop(['RemovedTeeth'],axis =1, inplace=True)

# %%
data.drop(['HadSkinCancer'],axis =1, inplace=True)

# %%
data.drop(['DeafOrHardOfHearing'],axis =1, inplace=True)

# %%
data.drop(['BlindOrVisionDifficulty'],axis =1, inplace=True)

# %%
data.drop(['DifficultyConcentrating'],axis =1, inplace=True)

# %%
data.drop(['DifficultyDressingBathing'],axis =1, inplace=True)

# %%
data.drop(['HeightInMeters'],axis =1, inplace=True)

# %%
data.drop(['HadCOPD'],axis =1, inplace=True)

# %%
data.drop(['HadAsthma'],axis =1, inplace=True)

# %%
data.drop(['HadKidneyDisease'],axis =1, inplace=True)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   State                  445132 non-null  object
#  1   Sex                    445132 non-null  object
#  2   GeneralHealth          443934 non-null  object
#  3   PhysicalHealthDays     434205 non-null  float64
#  4   MentalHealthDays       436065 non-null  float64
#  5   LastCheckupTime        436824 non-null  object
#  6   PhysicalActivities     444039 non-null  object
#  7   SleepHours             439679 non-null  float64
#  8   HadHeartAttack         442067 non-null  object
#  9   HadAngina              440727 non-null  object
#  10  HadStroke              443575 non-null  object
#  11  HadDepressiveDisorder  442320 non-null  object
#  12  HadKidneyDisease       443206 non-null  object
#  13  HadArthritis           442499 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth             1198
# PhysicalHealthDays       10927
# MentalHealthDays          9067
# LastCheckupTime           8308
# PhysicalActivities        1093
# SleepHours                5453
# HadHeartAttack            3065
# HadAngina                 4405
# HadStroke                 1557
# HadDepressiveDisorder     2812
# HadKidneyDisease          1926
# HadArthritis              2633
# HadDiabetes               1087
# DifficultyWalking        24012
# DifficultyErrands        25656
# SmokerStatus             35462
# ECigaretteUsage          35660
# ChestScan                56046
# RaceEthnicityCategory    14057
# AgeCategory               9079
# WeightInKilograms        42078
# BMI                      48806
# AlcoholDrinkers          46574
# HIVTesting               66127
# FluVaxLast12             47121
# PneumoVaxEver            77040
# TetanusLast10Tdap        82516
# HighRiskLastYear         50623
# ...

# %%
data['PhysicalActivities'] = data['PhysicalActivities'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\1715346369.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['PhysicalActivities'] = data['PhysicalActivities'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data['HadHeartAttack'] = data['HadHeartAttack'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\1740652218.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HadHeartAttack'] = data['HadHeartAttack'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data['AlcoholDrinkers'] = data['AlcoholDrinkers'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\1510741982.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['AlcoholDrinkers'] = data['AlcoholDrinkers'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data['HIVTesting'] = data['HIVTesting'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\741234820.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HIVTesting'] = data['HIVTesting'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data['FluVaxLast12'] = data['FluVaxLast12'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\147868610.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['FluVaxLast12'] = data['FluVaxLast12'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data['PneumoVaxEver'] = data['PneumoVaxEver'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\1024119701.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['PneumoVaxEver'] = data['PneumoVaxEver'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack HadAngina  ...      AgeCategory  \
# ...

# %%
data['HighRiskLastYear'] = data['HighRiskLastYear'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\2089131881.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HighRiskLastYear'] = data['HighRiskLastYear'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['CovidPos'] = data['CovidPos'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['HadAngina'] = data['HadAngina'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\3929659617.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HadAngina'] = data['HadAngina'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack  HadAngina  ...      AgeCategory  \
# ...

# %%
data['HadStroke'] = data['HadStroke'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\3859315341.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HadStroke'] = data['HadStroke'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['HadDepressiveDisorder'] = data['HadDepressiveDisorder'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\2403785628.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HadDepressiveDisorder'] = data['HadDepressiveDisorder'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['HadArthritis'] = data['HadArthritis'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\3359622431.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HadArthritis'] = data['HadArthritis'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['HadDiabetes'] = data['HadDiabetes'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['DifficultyWalking'] = data['DifficultyWalking'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\2623912818.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['DifficultyWalking'] = data['DifficultyWalking'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['ChestScan'] = data['ChestScan'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\3874703619.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['ChestScan'] = data['ChestScan'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data['AlcoholDrinkers'] = data['AlcoholDrinkers'].replace({'Yes': 1, 'No': 0}).infer_objects(copy=False)

# %%
data.drop(['DifficultyErrands'],axis =1, inplace=True)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack  HadAngina  ...      AgeCategory  \
# ...

# %%
data.to_csv('exported_heart_data.csv', index=False)

# %%
# handling the values of somkers :
#'Never smoked': 0
#'Former smoker': 0.25
#'Current smoker - now smokes some days':0.75
#'Current smoker - now smokes every day':1
data['SmokerStatus'] = data['SmokerStatus'].replace({'Never smoked': 0, 'Former smoker': 0.25, 'Current smoker - now smokes some days':0.75, 'Current smoker - now smokes every day':1}).infer_objects(copy=False)

# %%
data.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 0.0
# 1                                                NaN                 0.0
# 2  Within past year (anytime less than 12 months ...                 1.0
# 3  Within past year (anytime less than 12 months ...                 1.0
# 4  Within past year (anytime less than 12 months ...                 1.0
#
#    SleepHours  HadHeartAttack  HadAngina  ...      AgeCategory  \
# ...

# %%
data['SmokerStatus']
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.75
# 4         0.00
#           ...
# 445127    0.00
# 445128    0.00
# 445129    1.00
# 445130    0.00
# 445131    0.25
# Name: SmokerStatus, Length: 445132, dtype: float64

# %%
# handling the values of somkers:
#'Never used e-cigarettes in my entire life': 0
#'Not at all (right now)':0.25
#'Use them some days':0.75
#'Use them every day':1
data['ECigaretteUsage'] = data['ECigaretteUsage'].replace({'Never used e-cigarettes in my entire life': 0, 'Not at all (right now)':0.25,'Use them some days':0.75 ,'Use them every day':1}).infer_objects(copy=False)
# Out:
# C:\Users\taher\AppData\Local\Temp\ipykernel_8724\4133435871.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['ECigaretteUsage'] = data['ECigaretteUsage'].replace({'Never used e-cigarettes in my entire life': 0, 'Not at all (right now)':0.25,'Use them some days':0.75 ,'Use them every day':1}).infer_objects(copy=False)

# %%
# handling the values of somkers:
#'Never used e-cigarettes in my entire life': 0
#'Not at all (right now)':0.25
#'Use them some days':0.75
#'Use them every day':1
data['ECigaretteUsage'] = data['ECigaretteUsage'].replace({'Never used e-cigarettes in my entire life': 0, 'Not at all (right now)':0.25,'Use them some days':0.75 ,'Use them every day':1}).infer_objects(copy=False)

# %%
data['ECigaretteUsage']
# Out:
# 0         0.50
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
#           ...
# 445127    0.00
# 445128    0.00
# 445129    0.75
# 445130    0.00
# 445131    0.50
# Name: ECigaretteUsage, Length: 445132, dtype: float64

# %%
data.to_csv('exported_heart_data.csv', index=False)
